# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Line Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on using line charts to analyze trends over time and across different categories in a dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Track trends in compensation across age groups and specific age ranges.
#
# - Analyze job satisfaction trends based on experience level.
#
# - Explore and interpret line charts to identify patterns and trends.

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %% [markdown]
# #### Step 1: Download the dataset

# %%
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Out:
# --2025-09-18 10:51:34--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  50.3MB/s    in 3.0s
#
# 2025-09-18 10:51:38 (50.3 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]

# %% [markdown]
# #### Step 2: Import necessary libraries and load the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the data

# %%
df = pd.read_csv("survey-data.csv")

# %% [markdown]
# #### Display the first few rows to understand the structure of the data

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Trends in Compensation Over Age Groups

# %% [markdown]
# ##### 1. Line Chart of Median `ConvertedCompYearly` by Age Group

# %% [markdown]
# - Track how the median yearly compensation (ConvertedCompYearly) changes across different age groups.
#
# - Use a line chart to visualize these trends.

# %%
df_filtered = df.dropna(subset=["Age", "ConvertedCompYearly"])

df_filtered["ConvertedCompYearly"] = pd.to_numeric(df_filtered["ConvertedCompYearly"], errors='coerce')

median_comp_by_age = df_filtered.groupby("Age")["ConvertedCompYearly"].median().sort_index()

plt.figure(figsize=(10,6))
median_comp_by_age.plot(marker='o', linestyle='-', color='b')
plt.title("Median Yearly Compensation by Age Group", fontsize=16)
plt.xlabel("Age Group", fontsize=12)
plt.ylabel("Median Converted Compensation (Yearly)", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1085/2129463121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["ConvertedCompYearly"] = pd.to_numeric(df_filtered["ConvertedCompYearly"], errors='coerce')

# %% [markdown]
# ##### 2. Line Chart of Median `ConvertedCompYearly` for Ages 25 to 45

# %% [markdown]
# For a closer look, plot a line chart focusing on the median compensation for respondents between ages 25 and 45.

# %%
df_filtered = df.dropna(subset=["Age", "ConvertedCompYearly"])

df_filtered["ConvertedCompYearly"] = pd.to_numeric(df_filtered["ConvertedCompYearly"], errors='coerce')

age_order = ['25-34 years old', '35-44 years old']
df_filtered = df_filtered[df_filtered["Age"].isin(age_order)]

median_comp = df_filtered.groupby("Age")["ConvertedCompYearly"].median().reindex(age_order)

plt.figure(figsize=(8,5))
median_comp.plot(marker='o', linestyle='-', color='green')
plt.title("Median Yearly Compensation for Ages 25-45", fontsize=14)
plt.xlabel("Age Group", fontsize=12)
plt.ylabel("Median Converted Compensation (Yearly)", fontsize=12)
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1085/4057620165.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["ConvertedCompYearly"] = pd.to_numeric(df_filtered["ConvertedCompYearly"], errors='coerce')

# %% [markdown]
# ### Task 2: Trends in Job Satisfaction by Experience Level

# %% [markdown]
# ##### 1. Line Chart of Job Satisfaction (`JobSatPoints_6`) by Experience Level

# %% [markdown]
# - Use a column that approximates experience level to analyze how job satisfaction changes with experience.
#
# - If needed, substitute an available experience-related column for `Experience`.

# %%
df_filtered = df.dropna(subset=["YearsCodePro", "JobSatPoints_6"])

df_filtered["JobSatPoints_6"] = pd.to_numeric(df_filtered["JobSatPoints_6"], errors='coerce')

experience_bins = ["<1 year", "1-2 years", "3-5 years", "6-10 years", "11-20 years", ">20 years"]
df_filtered["Experience_Level"] = pd.cut(
    pd.to_numeric(df_filtered["YearsCodePro"].replace({"Less than 1 year": "0", "More than 50 years": "50"})),
    bins=[-1,1,2,5,10,20,100],
    labels=experience_bins
)

median_jobsat = df_filtered.groupby("Experience_Level")["JobSatPoints_6"].median().reindex(experience_bins)

plt.figure(figsize=(10,6))
median_jobsat.plot(marker='o', linestyle='-', color='blue')
plt.title("Job Satisfaction by Experience Level", fontsize=14)
plt.xlabel("Experience Level", fontsize=12)
plt.ylabel("Median Job Satisfaction (JobSatPoints_6)", fontsize=12)
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1085/2676564347.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["JobSatPoints_6"] = pd.to_numeric(df_filtered["JobSatPoints_6"], errors='coerce')
# /tmp/ipykernel_1085/2676564347.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["Experience_Level"] = pd.cut(
# ...

# %% [markdown]
# ### Task 3: Trends in Job Satisfaction and Compensation by Experience

# %% [markdown]
# ##### 1.Line Chart of Median ConvertedCompYearly Over Experience Level
#
# - This line chart will track how median compensation (`ConvertedCompYearly`) changes with increasing experience.
#
# - Use a column such as `WorkExp` or another relevant experience-related column.

# %%
df_filtered = df.dropna(subset=["YearsCodePro", "ConvertedCompYearly"])

df_filtered["ConvertedCompYearly"] = pd.to_numeric(df_filtered["ConvertedCompYearly"], errors='coerce')

df_filtered["YearsCodeProNum"] = df_filtered["YearsCodePro"].replace({
    "Less than 1 year": 0,
    "More than 50 years": 50
}).astype(float)

experience_bins = ["<1 year", "1-2 years", "3-5 years", "6-10 years", "11-20 years", ">20 years"]
df_filtered["Experience_Level"] = pd.cut(
    df_filtered["YearsCodeProNum"],
    bins=[-1,1,2,5,10,20,100],
    labels=experience_bins
)

median_comp = df_filtered.groupby("Experience_Level")["ConvertedCompYearly"].median().reindex(experience_bins)

plt.figure(figsize=(10,6))
median_comp.plot(marker='o', linestyle='-', color='green')
plt.title("Median Compensation by Experience Level", fontsize=14)
plt.xlabel("Experience Level", fontsize=12)
plt.ylabel("Median ConvertedCompYearly ($)", fontsize=12)
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1085/3853164405.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["ConvertedCompYearly"] = pd.to_numeric(df_filtered["ConvertedCompYearly"], errors='coerce')
# /tmp/ipykernel_1085/3853164405.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["YearsCodeProNum"] = df_filtered["YearsCodePro"].replace({
# /tmp/ipykernel_1085/3853164405.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ##### 2.Line Chart of Job Satisfaction (`JobSatPoints_6`) Across Experience Levels
#
# - Create a line chart to explore trends in job satisfaction (`JobSatPoints_6`) based on experience level.
#
# - This chart will provide insight into how satisfaction correlates with experience over time

# %%
df_filtered = df.dropna(subset=["YearsCodePro", "JobSatPoints_6"])

df_filtered["JobSatPoints_6"] = pd.to_numeric(df_filtered["JobSatPoints_6"], errors='coerce')

df_filtered["YearsCodeProNum"] = df_filtered["YearsCodePro"].replace({
    "Less than 1 year": 0,
    "More than 50 years": 50
}).astype(float)

experience_bins = ["<1 year", "1-2 years", "3-5 years", "6-10 years", "11-20 years", ">20 years"]
df_filtered["Experience_Level"] = pd.cut(
    df_filtered["YearsCodeProNum"],
    bins=[-1,1,2,5,10,20,100],
    labels=experience_bins
)

median_job_sat = df_filtered.groupby("Experience_Level")["JobSatPoints_6"].median().reindex(experience_bins)

plt.figure(figsize=(10,6))
median_job_sat.plot(marker='o', linestyle='-', color='blue')
plt.title("Median Job Satisfaction by Experience Level", fontsize=14)
plt.xlabel("Experience Level", fontsize=12)
plt.ylabel("Median JobSatPoints_6", fontsize=12)
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1085/56282005.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["JobSatPoints_6"] = pd.to_numeric(df_filtered["JobSatPoints_6"], errors='coerce')
# /tmp/ipykernel_1085/56282005.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["YearsCodeProNum"] = df_filtered["YearsCodePro"].replace({
# /tmp/ipykernel_1085/56282005.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# #### Final Step: Review

# %% [markdown]
# In this lab, you focused on analyzing trends in compensation and job satisfaction, specifically exploring how these metrics change with age and experience levels using line charts.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you explored essential data visualization techniques with a focus on analyzing trends using line charts. You learned to:
#
# - Visualize the distribution of compensation across age groups to understand salary trends.
#
# - Track changes in median compensation over various experience levels, identifying how earnings progress with experience.
#
# - Examine trends in job satisfaction by experience, revealing how satisfaction varies throughout a developer's career.
#
# These analyses allow for a deeper understanding of how factors like age and experience influence job satisfaction and compensation. By using line charts, you gained insights into continuous data patterns, which are invaluable for interpreting professional trends in the developer community.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
